# %%
import subprocess

process = subprocess.Popen(
    ["python", "drug_pipeline.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    universal_newlines=True
)

for line in process.stdout:
    print(line, end="")  
process.wait()
# Out:
# 2025-10-08 05:48:51.566078: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2025-10-08 05:48:51.566722: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Starting Drug Classification Pipeline
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Generating ephemeral wheel package for 'C:\\drug-pipeline\\modules\\drug_class_transform.py' (including modules: ['components', 'drug_class_trainer', 'drug_class_transform', 'drug_class_tuner']).
# INFO:absl:User module package has hash fingerprint version 59a63e73eaee4753b95d9b7b65b1f947f025cbacc2158455350be9cd3970c3b9.
# ...
